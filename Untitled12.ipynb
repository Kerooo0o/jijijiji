# %%
firstlist = ["baitsaa", "tums", "luuvan"]
print(firstlist[-1])
# Out:
# luuvan

# %%
YouTubeVideo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-24a3cec5a390> in <cell line: 0>()
# ----> 1 YouTubeVideo
#
# NameError: name 'YouTubeVideo' is not defined

# %%
from IPython.display import YouTubeVideo
video = YouTubeVideo("lX3LCRwiHbDl7Gnx")
display(video)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/lX3LCRwiHbDl7Gnx"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
mytodo= ["meet friends", "go to skatepark", "go to grocery store"]
for i in mytodo:
    print(i)
# Out:
# go to gym
# go to grocery store
# go to the bank

# %%
mytodo= ["meet friends", "go to skatepark", "go to grocery store"]
one = input()
if one in mytodo:
    print(one + " - hiih jagsaaltad baina")
else:
    print(one + " - hiih chagsaaltad alga")
# Out:
# n
# n - hiih chagsaaltad alga

# %%
height= [150,171,160,167,175,456,3456,987,567,568,457]

for one in height:
  if one > 160:
    print(one)
# Out:
# 171
# 167
# 175
# 456
# 3456
# 987
# 567
# 568
# 457

# %%
lsttt= ["a","b","c"]
for i in range(3):
  if lsttt[2] == "c":
    print("yes")
  else:
    print(lsttt[i])
# Out:
# yes
# yes
# yes

# %%
# Out:
# 3

# %%
ner = []
for i in range(3):
    a = input()
    ner.append(a)
print(ner)
# Out:
# baldan
# bataa
# dulmantseren
# ['baldan', 'bataa', 'dulmantseren']

# %%
ner = []
ner1 = input()
ner2 = input()
ner3 = input()
ner.append(ner1)
ner.append(ner2)
ner.append(ner3)
print(ner)
# Out:
# baldan
# boldoo
# dulmantseren
# ['baldan', 'boldoo', 'dulmantseren']
