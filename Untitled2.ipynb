# %%
  def inflate_balloon(n):
  for i in range(n):
    for j in range(i + 1):
      print("🎈", end="")
    print()
  print("💥")
inflate_balloon(3)
# Out:
# 🎈
# 🎈🎈
# 🎈🎈🎈
# 💥

# %%
def build_tower(n):
  for i in range(n):
    for j in range(i + 1):
      print("*", end="")
    print()
build_tower(4)
# Out:
# **
# ***
# ****
# *****

# %%
import random
onoloo=0
onoogui=0
def archery_game(n):
  for i in range(n):
    target=random.choice(["onoloo", "onoogui"])
    print(target)
    if target=="onoloo":
      onoloo+=1
    else:
      onoogui+=1
  print("onoloo:", onoloo)
  print("onoogui:", onoogui)
archery_game(10)
# Out:
# onoogui
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-109-ede187b96d2d> in <cell line: 0>()
#      12   print("onoloo:", onoloo)
#      13   print("onoogui:", onoogui)
# ---> 14 archery_game(10)
#
# <ipython-input-109-ede187b96d2d> in archery_game(n)
#       9       onoloo+=1
#      10     else:
# ---> 11       onoogui+=1
#      12   print("onoloo:", onoloo)
#      13   print("onoogui:", onoogui)
#
# UnboundLocalError: cannot access local variable 'onoogui' where it is not associated with a value

# %%
import random
def archery_game():
  onoo = 0
  ono0 = 0
  for i in range(10):
    result = random.choice(["onoloo", "onoogui"])
    print(result)
    if result == "onoogui":
      ono0 += 1
    if result == "onoloo":
      onoo += 1
  print("10 aas onoj chadsan onoo:", onoo)
  print("10 aas onoj chadaagui:", ono0)
archery_game()
# Out:
# onoloo
# onoogui
# onoloo
# onoloo
# onoogui
# onoloo
# onoogui
# onoloo
# onoloo
# onoloo
# 10 aas onoj chadsan onoo: 7
# 10 aas onoj chadaagui: 3

# %%
import random
def roll_dice(n):


  for i in range(i + 2):
    print(i)
roll_dice(1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-71-58dcb5fc2909> in <cell line: 0>()
#       4   for i in range(i + 2):
#       5     print(i)
# ----> 6 roll_dice(1)
#
# <ipython-input-71-58dcb5fc2909> in roll_dice(n)
#       2 def roll_dice(n):
#       3
# ----> 4   for i in range(i + 2):
#       5     print(i)
#       6 roll_dice(1)
#
# UnboundLocalError: cannot access local variable 'i' where it is not associated with a value

# %%
import random
def roll_dice(n):


  for i in range(n):
    roll=random.randint(1,6)
    print(roll)
roll_dice(3)
# Out:
# 5
# 4
# 3

# %%
def pyramid(n):
  for i in range(n):
    for j in range(i + 1):
      print("*", end="")
    print()
pyramid(5)
# Out:
# *
# **
# ***
# ****
# *****

# %%
def pyramid(n):
  for i in range(n):
    for j in range(i + 1):
      print("*", end="")
    print()
pyramid(5)
# Out:
# *
# **
# ***
# ****
# *****

# %%
def pyramid(n):
  for i in range(1, n + 1):
    print(" "(n - i) + "*" * (2 * i - 1))
pyramid(5)
# Out:
# <>:3: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <ipython-input-226-bbe0a13f68e7>:3: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print(" "(n - i) + "*" * (2 * i - 1))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-226-bbe0a13f68e7> in <cell line: 0>()
#       2   for i in range(1, n + 1):
#       3     print(" "(n - i) + "*" * (2 * i - 1))
# ----> 4 pyramid(5)
#       5
#       6
#
# <ipython-input-226-bbe0a13f68e7> in pyramid(n)
#       1 def pyramid(n):
#       2   for i in range(1, n + 1):
# ----> 3     print(" "(n - i) + "*" * (2 * i - 1))
#       4 pyramid(5)
#       5
#
# TypeError: 'str' object is not callable

# %%
def pyramid(n):
  for i in range(1, n + 1):
    print(" " * (n - i) + "*" * (2 * i - 1))
pyramid(5)
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
def pyramid(n):
  for i in range

# %%
print("random float :", random.random())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-147f7250a4fa> in <cell line: 0>()
# ----> 1 print("random float :", random.random())
#
# NameError: name 'random' is not defined

# %%
import random
random.shuffle(items)
items = ['apple','banana','cherry','watermelon']
print("random choice:", random.choice(items))
print("random shuffle:", items)
print("sample:", random.sample(items,2))
# Out:
# random choice: watermelon
# random shuffle: ['apple', 'banana', 'cherry', 'watermelon']
# sample: ['banana', 'cherry']

# %%
import random
import random
print("Hello! What is your name?")
a = input()
print("Well, " + a + ", I am thinking of a number between 1 and 20.")
print("Take a guess.")
number = random.randint(1,20)
for i in range(1,20):
  guess = int(input())
  if guess < number:
    print("Your guess is too low.")
  if guess > number:
    print("Your guess is too high.")
  if guess == number:
    break
print("good job," + a + "! you guessed my number in"+ guess)
# Out:
# Hello! What is your name?
# kero
# Well, kero, I am thinking of a number between 1 and 20.
# Take a guess.
# 5
# Your guess is too low.
# 6
# Your guess is too low.
# 7
# Your guess is too low.
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-ea1cb257bd97> in <cell line: 0>()
#      14   if guess == number:
#      15     break
# ---> 16 print("good job," + a + "! you guessed my number in"+ guess)
#
# TypeError: can only concatenate str (not "int") to str

# %%
import random
import random
print("Hello! What is your name?")
a = input()
print("Well, " + a + ", I am thinking of a number between 1 and 20.")
print("Take a guess.")
number = random.randint(1,20)
for i in range(1,20):
  guess = int(input())
  if guess < number:
    print("Your guess is too low.")
  if guess > number:
    print("Your guess is too high.")
  if guess == number:
    break
# Out:
# Hello! What is your name?
# 6
# Well, 6, I am thinking of a number between 1 and 20.
# Take a guess.
# 6
# Your guess is too low.
# 7
# Your guess is too low.
# 9
# Your guess is too low.
# 11
# Your guess is too low.
# 19
# Your guess is too low.
# 20

# %%
import random
a = input()
print("Hello! What is your name?")
print("well" + a + "")

# %%
import random
import random
print("Hello! What is your name?")
a = input()
print("Well, " + a + ", I am thinking of a number between 1 and 20.")
print("Take a guess.")
number = random.randint(1,20)
while True:
  guess = int(input())
  if guess < number:
    print("Your guess is too low.")
  if guess > number:
    print("Your guess is too high.")
  if guess == number:

    break
# Out:
# Hello! What is your name?
# k
# Well, k, I am thinking of a number between 1 and 20.
# Take a guess.
# 6
# Your guess is too low.
# 0
# Your guess is too low.
# 10
# Your guess is too low.
# 17
# Your guess is too high.
# 16
# Your guess is too high.
# 15
# Your guess is too high.
# 14
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-811524fcdb95> in <cell line: 0>()
#      13     print("Your guess is too high.")
#      14   if guess == number:
# ---> 15     print("good job," + a + "! you guessed my number in"+ guess)
#      16     break
#
# TypeError: can only concatenate str (not "int") to str
