# %%
# Out:
# 34 34 34
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d0abe15cbef0> in <cell line: 0>()
#       3 c = int(a[1])
#       4 d = int(a[2])
# ----> 5 print(a + b + c + d)
#
# TypeError: can only concatenate list (not "int") to list

# %%
a =
# Out:
# 1
# 2
# 12

# %%
a = input().split()
b = int(a[0])
c = int(a[1])
d = int(a[2])
# Out:
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-b672b834e1f2> in <cell line: 0>()
#       1 a = input().split()
#       2 b = int(a[0])
# ----> 3 c = int(a[1])
#       4 d = int(a[2])
#
# IndexError: list index out of range

# %%
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-726116d77613> in <cell line: 0>()
#       1 a = input().split()
# ----> 2 print(int(a))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
a = input()
b = input()
print(int(a += b))
# Out:
#   File "<ipython-input-25-4760618bf819>", line 3
#     print(int(a += b))
#                 ^
# SyntaxError: invalid syntax

# %%
# Out:
# 476
# 476

# %%
a= input().split()
print(int([a*6]))
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-eb61ade14e2f> in <cell line: 0>()
#       1 a= input().split()
# ----> 2 print(int([a*6]))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
a = input().split()
print(int(a*a) + int(a*6))
# Out:
#   File "<ipython-input-51-bd09423810f3>", line 2
#     b = print(int(a*a) + int(a*6))
#     ^
# IndentationError: unexpected indent

# %%
a = input().split()
