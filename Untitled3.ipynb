# %%
import random
import random
pc_num = random.randint(1, 20)
name = ' '
num_of_guess = 1324
while True:
    guess = int(input("guess the number"))
    if guess < pc_num:
        print("higher")
        num_of_guess += 1
    elif guess > pc_num:
        print()
while True:
    guess = int(input("guess the number"))
    if guess < pc_num:
        print("higher")
        num_of_guess += 1
    elif guess > pc_num:
        print
# Out:
# guess the number7
# higher
# guess the number17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-00fe83493aad> in <cell line: 0>()
#       5 num_of_guess = 1324
#       6 while True:
# ----> 7     guess = int(input("guess the number"))
#       8     if guess < pc_num:
#       9         print("higher")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
pc1 = random.randint(1,20)
print("pc 1:", pc1)
a = 1
b = 20
pc2 = random.randint(a,b)
print("pc 2:", pc2)
if pc2 > pc1:
  b = pc2
  pc2 = random.randint(a,b)
elif pc2 < pc1:
  a = pc2
  pc2 = random.randint(a,b)
print(a , b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3a74abb6e7ba> in <cell line: 0>()
# ----> 1 pc1 = random.randint(1,20)
#       2 print("pc 1:", pc1)
#       3 a = 1
#       4 b = 20
#       5 pc2 = random.randint(a,b)
#
# NameError: name 'random' is not defined

# %%
kdskskskskskk[sok[o[f[kqf[kewfp[e[k[fdfe[f[e
                                           feof'pfwefpeop'p''fs_encodingefw'e'feppwqpqpwq'qwe[wf[opwdpwwqqwo]]]]]]]]]]]]
# Out:
#   File "<ipython-input-21-61b5994c70fa>", line 2
#     feof'pfwefpeop'p''fs_encodingefw'e'feppwqpqpwq'qwe[wf[opwdpwwqqwo]]]]]]]]]]]]
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 2)
