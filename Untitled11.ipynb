# %%
a = input()
if a < 15:
    print("YES")
elif a > 15:
    print("NO")
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f779ea94ed74> in <cell line: 0>()
#       1 a = input()
# ----> 2 if a < 15:
#       3     print("YES")
#       4 elif a > 15:
#       5     print("NO")
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
a = input()
a = int(a)
if a < 15:
    print("YES")
elif a > 15:
    print("NO")
# Out:
# 12
# YES
