# %%
a = input().split()
print(int(a * a))
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2b7720973d3b> in <cell line: 0>()
#       1 a = input().split()
# ----> 2 print(int(a * a))
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
a, b = 5, 4
num = 19
floor1 = num // b
floor2 = num % b
if floor2 < 10 and floor2 > 0:
	floor1 = floor1 + 1
print(floor1)
# Out:
# 5

# %%
a = input().split()
num = int(a[0])
result = num * num
print(result)
# Out:
# 3
# 9
