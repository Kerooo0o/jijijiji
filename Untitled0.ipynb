# %%
import random
a == input()
print("hheelllloo whats your name")
print("well"  + a + "i am thinkig of a number between 1 and 20")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3ca9b30aba5> in <cell line: 0>()
#       1 import random
# ----> 2 a == input()
#       3 print("hheelllloo whats your name")
#       4 print("well"  + a + "i am thinkig of a number between 1 and 20")
#       5
#
# NameError: name 'a' is not defined

# %%
import random
pc_num = random.randint(1, 20)
name = ' '
 num_of_guess = 1
 while true:
  guess = int(input("guess the number"))
  if guess < pc_num
  print("higher")
  num_of_guess += 1
  elif guess > pc_num:
    print("lower")
    num_of_guess += 1
else:
  print(f"right!, you guessed after{num_of_guess} tries!.")
  break
# Out:
#   File "<ipython-input-2-33abe6f482c3>", line 4
#     num_of_guess = 1
#     ^
# IndentationError: unexpected indent
